# %% [markdown]
# ![image.png](attachment:8376c088-3eab-497f-813a-1259642de634.png)

# %%
# %pwd
# Out:
# '/Users/TomAndLiza/PycharmProjects/gitmaster'

# %%
# %ls
# Out:
# 3-1.2ExcecptionHandling.ipynb
# apple.json
# bamboo_tree.dot
# bitcoin_chart.html
# DS0103EN-Exercise-From-Modeling-to-Evaluation.ipynb
# DS0103EN-Exercise-From-Understanding-to-Preparation.ipynb
# employee.csv
# Final-Assignment Library-v2.ipynb
# Golden_State.pkl
# image.png
# INSTRUCTOR.db
# INSTRUCTOR.db-journal
# new_sample.xml
# notebook.ipynb
# person.json
# pokemon.py
# PY0101EN-3-3-Functions-v2.ipynb
# PY0101EN-5.1_Intro_API.ipynb
# PY0101EN-5.2_API_2.v2.ipynb
# PY0101EN-5.3_Requests_HTTP.ipynb
# PY0101EN-5.ipynb
# pycoingecko example.ipynb
# README.md
# Revenue Data and Building a Dashboard-v1.ipynb
# Sample-employee-XML-file.xml
# sample.json
# sample.xlsx
# scrapbook 2.py
# scrapbook.py
# snake game.py
# sql
# tank game.py
# tomtest.py
# WebScraping_Review_Lab.ipynb
# WebScraping-Review-Lab-v2.ipynb
# Week4-Insert-Update-SQLite-v2.ipynb
# yahoo example.ipynb

# %%
# %history
# Out:
# %pwd
# %ls
# %history

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %code_wrap  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %mamba  %man  %matplotlib  %micromamba  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %subshell  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %who
# Out:
# Interactive namespace is empty.

# %%
# %%bash
# echo "Hello World"
# Out:
# Hello World

# %%
# %%javascript
# const newWindow = window.open('about:blank', '_blank');
# newWindow.document.write('<h1>Hello World!</h1>');

# %%
# %%HTML
# <button onclick="openTab()">Click Me</button>
#
# <script>
#   function openTab() {
#     const myTab = window.open('', '_blank');
#     myTab.document.write('Hello World!');
#   }
# </script>
# Out:
# <button onclick="openTab()">Click Me</button>
#
# <script>
#   function openTab() {
#     const myTab = window.open('', '_blank');
#     myTab.document.write('Hello World!');
#   }
# </script>
